# %% [markdown]
# # Explore here

# %%
import joblib
import streamlit as st
import os
from sklearn.tree import DecisionTreeClassifier

# Ruta al archivo del modelo
ruta_modelo = "/workspaces/fraud_para_Render/models/modelo_Arbol_inicial.pkl"

# Verificar la existencia del archivo del modelo
if not os.path.exists(ruta_modelo):
    raise FileNotFoundError(f"El archivo {ruta_modelo} no existe")

# Cargar el modelo
model = joblib.load(ruta_modelo)

# Verificar si el modelo está cargado correctamente
if not isinstance(model, DecisionTreeClassifier):
    raise TypeError("El archivo cargado no es un modelo Arbol")

# Diccionario de clases
class_dict = {
    "0": "No Fraude",
    "1": "Fraude",
}

# Título de la aplicación
st.title("MODELO MACHINE LEARNING PARA LA PREDICCION DE FRAUDE FINANCIERO")

# Menú de navegación
menu = st.sidebar.selectbox("Selecciona una opción", ["Predicción de Fraude", "Reseña sobre Fraudes Financieros"])

if menu == "Predicción de Fraude":
    st.header("Predicción de Fraude en Transacciones Bancarias")

    # Formularios para ingresar los valores de manera estructurada
    with st.form("Formulario de Datos"):
        st.subheader("Por favor, complete la siguiente información")
        income = st.number_input("Ingresos", min_value=0.0, max_value=1000000.0, step=1000.0)
        name_email_similarity = st.slider("Similitud entre Nombre y Email", min_value=0.0, max_value=1.0, step=0.01)
        prev_address_months_count = st.number_input("Meses en la Dirección Anterior", min_value=0, max_value=240, step=1)
        current_address_months_count = st.number_input("Meses en la Dirección Actual", min_value=0, max_value=240, step=1)
        customer_age = st.number_input("Edad del Cliente", min_value=18, max_value=100, step=1)
        days_since_request = st.number_input("Días desde la Solicitud", min_value=0.0, max_value=365.0, step=1.0)
        intended_balcon_amount = st.number_input("Monto del Saldo Intencionado", min_value=0.0, max_value=1000000.0, step=1000.0)
        zip_count_4w = st.number_input("Conteo de Códigos Postales en 4 Semanas", min_value=0, max_value=50, step=1)
        velocity_6h = st.number_input("Velocidad de Transacción en 6 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_24h = st.number_input("Velocidad de Transacción en 24 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_4w = st.number_input("Velocidad de Transacción en 4 Semanas", min_value=0.0, max_value=1000.0, step=1.0)
        bank_branch_count_8w = st.number_input("Número de Sucursales Bancarias en 8 Semanas", min_value=0, max_value=20, step=1)
        date_of_birth_distinct_emails_4w = st.number_input("Correos Electrónicos Distintos en 4 Semanas", min_value=0, max_value=10, step=1)
        credit_risk_score = st.number_input("Puntuación de Riesgo Crediticio", min_value=0, max_value=1000, step=1)
        email_is_free = st.selectbox("Email es Gratuito", [0, 1])
        phone_home_valid = st.selectbox("Teléfono de Casa Válido", [0, 1])
        phone_mobile_valid = st.selectbox("Teléfono Móvil Válido", [0, 1])
        bank_months_count = st.number_input("Meses con el Banco", min_value=0, max_value=240, step=1)
        has_other_cards = st.selectbox("Tiene Otras Tarjetas", [0, 1])
        proposed_credit_limit = st.number_input("Límite de Crédito Propuesto", min_value=0.0, max_value=1000000.0, step=1000.0)
        foreign_request = st.selectbox("Solicitud Extranjera", [0, 1])
        session_length_in_minutes = st.number_input("Duración de la Sesión en Minutos", min_value=0.0, max_value=1440.0, step=1.0)
        device_distinct_emails_8w = st.number_input("Emails Distintos en 8 Semanas", min_value=0, max_value=10, step=1)
        device_fraud_count = st.number_input("Conteo de Fraudes en el Dispositivo", min_value=0, max_value=10, step=1)
        month = st.slider("Mes", min_value=1, max_value=12, step=1)

        # Botón de predicción
        submit_button = st.form_submit_button(label="Predecir")

    if submit_button:
        data = [[
            income, name_email_similarity, prev_address_months_count, current_address_months_count, customer_age,
            days_since_request, intended_balcon_amount, zip_count_4w, velocity_6h, velocity_24h, velocity_4w,
            bank_branch_count_8w, date_of_birth_distinct_emails_4w, credit_risk_score, email_is_free, phone_home_valid,
            phone_mobile_valid, bank_months_count, has_other_cards, proposed_credit_limit, foreign_request,
            session_length_in_minutes, device_distinct_emails_8w, device_fraud_count, month
        ]]
        
        prediction = str(model.predict(data)[0])
        pred_class = class_dict[prediction]
        st.write("Predicción:", pred_class)

elif menu == "Reseña sobre Fraudes Financieros":
    st.header("Reseña sobre Fraudes Financieros")

    st.write("""
    Los fraudes financieros son actividades ilícitas que buscan obtener ganancias económicas mediante engaños y estafas. 
    Existen diferentes tipos de fraudes financieros, entre ellos:

    1. **Fraude con Tarjetas de Crédito**: Clonación o robo de datos de tarjetas para realizar compras no autorizadas.
    2. **Phishing**: Intento de obtener información confidencial como contraseñas o detalles bancarios mediante correos electrónicos falsos o sitios web fraudulentos.
    3. **Fraude en Transferencias Bancarias**: Manipulación o redirección de transferencias electrónicas hacia cuentas no autorizadas.
    4. **Fraude en Préstamos**: Obtención de préstamos con identidades falsas o documentos falsificados.
    5. **Fraude en Inversiones**: Promesas de altos rendimientos con esquemas Ponzi o inversiones inexistentes.

    Las medidas de prevención y detección incluyen el monitoreo continuo de transacciones, implementación de tecnologías avanzadas de seguridad y educación a los usuarios sobre prácticas seguras.
    """)
# Out:
# 2025-02-03 18:03:31.689 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.726
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vscode/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-03 18:03:31.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.732 Session state does not function when running a script without `streamlit run`
# 2025-02-03 18:03:31.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 18:03:31.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import os

# Ruta del archivo que quieres verificar
ruta_archivo = '/workspaces/fraud_para_Render/models/modelo_Arbol_optimizado.pkl'

# Verificar si el archivo existe
if os.path.exists(ruta_archivo):
    print(f"El archivo {ruta_archivo} existe.")
else:
    print(f"El archivo {ruta_archivo} no se encuentra en la ruta especificada.")
# Out:
# El archivo /workspaces/fraud_para_Render/models/modelo_Arbol_optimizado.pkl existe.
