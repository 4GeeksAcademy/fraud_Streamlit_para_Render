# %% [markdown]
# # Explore here

# %%
import joblib
import streamlit as st
import os
from sklearn.ensemble import RandomForestClassifier

# Verificación de la existencia del archivo del modelo
ruta_modelo = "/workspaces/fraud_para_Render/models/modelo_RandomForest_optimizado.pkl"

if os.path.exists(ruta_modelo):
    print(f"El archivo {ruta_modelo} existe")
else:
    raise FileNotFoundError(f"El archivo {ruta_modelo} no existe")

# Cargar el modelo
model = joblib.load(ruta_modelo)

# Verificar si el modelo está cargado correctamente
if not isinstance(model, RandomForestClassifier):
    raise TypeError("El archivo cargado no es un modelo RandomForest")

# Diccionario de clases
class_dict = {
    "0": "No Fraude",
    "1": "Fraude",
}

# Título de la aplicación
st.title("MODELO MACHINE LEARNING PARA LA PREDICCION DE FRAUDE FINANCIERO")

# Menú de navegación
menu = st.sidebar.selectbox("Selecciona una opción", ["Predicción de Fraude", "Reseña sobre Fraudes Financieros"])

if menu == "Predicción de Fraude":
    st.header("Predicción de Fraude en Transacciones Bancarias")

    # Formularios para ingresar los valores de manera estructurada
    with st.form("Formulario de Datos"):
        st.subheader("Por favor, complete la siguiente información")
        income = st.number_input("Ingresos", min_value=0.0, max_value=1000000.0, step=1000.0)
        name_email_similarity = st.slider("Similitud entre Nombre y Email", min_value=0.0, max_value=1.0, step=0.01)
        prev_address_months_count = st.number_input("Meses en la Dirección Anterior", min_value=0, max_value=240, step=1)
        current_address_months_count = st.number_input("Meses en la Dirección Actual", min_value=0, max_value=240, step=1)
        customer_age = st.number_input("Edad del Cliente", min_value=18, max_value=100, step=1)
        days_since_request = st.number_input("Días desde la Solicitud", min_value=0.0, max_value=365.0, step=1.0)
        intended_balcon_amount = st.number_input("Monto del Saldo Intencionado", min_value=0.0, max_value=1000000.0, step=1000.0)
        zip_count_4w = st.number_input("Conteo de Códigos Postales en 4 Semanas", min_value=0, max_value=50, step=1)
        velocity_6h = st.number_input("Velocidad de Transacción en 6 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_24h = st.number_input("Velocidad de Transacción en 24 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_4w = st.number_input("Velocidad de Transacción en 4 Semanas", min_value=0.0, max_value=1000.0, step=1.0)
        bank_branch_count_8w = st.number_input("Número de Sucursales Bancarias en 8 Semanas", min_value=0, max_value=20, step=1)
        date_of_birth_distinct_emails_4w = st.number_input("Correos Electrónicos Distintos en 4 Semanas", min_value=0, max_value=10, step=1)
        credit_risk_score = st.number_input("Puntuación de Riesgo Crediticio", min_value=0, max_value=1000, step=1)
        email_is_free = st.selectbox("Email es Gratuito", [0, 1])
        phone_home_valid = st.selectbox("Teléfono de Casa Válido", [0, 1])
        phone_mobile_valid = st.selectbox("Teléfono Móvil Válido", [0, 1])
        bank_months_count = st.number_input("Meses con el Banco", min_value=0, max_value=240, step=1)
        has_other_cards = st.selectbox("Tiene Otras Tarjetas", [0, 1])
        proposed_credit_limit = st.number_input("Límite de Crédito Propuesto", min_value=0.0, max_value=1000000.0, step=1000.0)
        foreign_request = st.selectbox("Solicitud Extranjera", [0, 1])
        session_length_in_minutes = st.number_input("Duración de la Sesión en Minutos", min_value=0.0, max_value=1440.0, step=1.0)
        device_distinct_emails_8w = st.number_input("Emails Distintos en 8 Semanas", min_value=0, max_value=10, step=1)
        device_fraud_count = st.number_input("Conteo de Fraudes en el Dispositivo", min_value=0, max_value=10, step=1)
        month = st.slider("Mes", min_value=1, max_value=12, step=1)

        # Botón de predicción
        submit_button = st.form_submit_button(label="Predecir")

    if submit_button:
        data = [[
            income, name_email_similarity, prev_address_months_count, current_address_months_count, customer_age,
            days_since_request, intended_balcon_amount, zip_count_4w, velocity_6h, velocity_24h, velocity_4w,
            bank_branch_count_8w, date_of_birth_distinct_emails_4w, credit_risk_score, email_is_free, phone_home_valid,
            phone_mobile_valid, bank_months_count, has_other_cards, proposed_credit_limit, foreign_request,
            session_length_in_minutes, device_distinct_emails_8w, device_fraud_count, month
        ]]
        
        prediction = str(model.predict(data)[0])
        pred_class = class_dict[prediction]
        st.write("Predicción:", pred_class)

elif menu == "Reseña sobre Fraudes Financieros":
    st.header("Reseña sobre Fraudes Financieros")

    st.write("""
    Los fraudes financieros son actividades ilícitas que buscan obtener ganancias económicas mediante engaños y estafas. 
    Existen diferentes tipos de fraudes financieros, entre ellos:

    1. **Fraude con Tarjetas de Crédito**: Clonación o robo de datos de tarjetas para realizar compras no autorizadas.
    2. **Phishing**: Intento de obtener información confidencial como contraseñas o detalles bancarios mediante correos electrónicos falsos o sitios web fraudulentos.
    3. **Fraude en Transferencias Bancarias**: Manipulación o redirección de transferencias electrónicas hacia cuentas no autorizadas.
    4. **Fraude en Préstamos**: Obtención de préstamos con identidades falsas o documentos falsificados.
    5. **Fraude en Inversiones**: Promesas de altos rendimientos con esquemas Ponzi o inversiones inexistentes.

    Las medidas de prevención y detección incluyen el monitoreo continuo de transacciones, implementación de tecnologías avanzadas de seguridad y educación a los usuarios sobre prácticas seguras.
    """)
# Out:
# El archivo /workspaces/fraud_para_Render/models/modelo_RandomForest_optimizado.pkl existe
# 2025-02-03 19:02:17.211 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.478
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vscode/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-03 19:02:17.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.490 Session state does not function when running a script without `streamlit run`
# 2025-02-03 19:02:17.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-03 19:02:17.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
